# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn import model_selection
from sklearn import preprocessing
import warnings

# %%
df_train = pd.read_csv('../input/tabular-playground-series-sep-2021/train.csv', index_col='id')
test = pd.read_csv('../input/tabular-playground-series-sep-2021/test.csv')
submission_data = pd.read_csv('../input/tabular-playground-series-sep-2021/sample_solution.csv')

df_train.head()
# Out:
#          f1        f2         f3        f4       f5        f6       f7  \
# id
# 0   0.10859  0.004314    -37.566  0.017364  0.28915 -10.25100   135.12
# 1   0.10090  0.299610  11822.000  0.276500  0.45970  -0.83733  1721.90
# 2   0.17803 -0.006980    907.270  0.272140  0.45948   0.17327  2298.00
# 3   0.15236  0.007259    780.100  0.025179  0.51947   7.49140   112.51
# 4   0.11623  0.502900   -109.150  0.297910  0.34490  -0.40932  2538.90
#
#           f8            f9        f10  ...     f110    f111     f112  \
# id                                     ...
# 0   168900.0  3.992400e+14     86.489  ... -12.2280  1.7482  1.90960
# 1   119810.0  3.874100e+15   9953.600  ... -56.7580  4.1684  0.34808
# 2   360650.0  1.224500e+13  15827.000  ...  -5.7688  1.2042  0.26290
# 3   259490.0  7.781400e+13    -36.837  ... -34.8580  2.0694  0.79631
# 4    65332.0  1.907200e+15    144.120  ... -13.6410  1.5298  1.14640
#
#         f113      f114    f115          f116    f117     f118  claim
# id
# ...

# %%
features = df_train.columns[:-1]
target = df_train.columns[-1]
df_train['nan_count'] = df_train.isnull().sum(axis=1)
test['nan_count'] = test.isnull().sum(axis=1)
#features.append('nan_count')
features_list = list(features)
features_list.append('nan_count')
features_list
# Out:
# ['f1',
#  'f2',
#  'f3',
#  'f4',
#  'f5',
#  'f6',
#  'f7',
#  'f8',
#  'f9',
#  'f10',
#  'f11',
#  'f12',
#  'f13',
#  'f14',
#  'f15',
#  'f16',
#  'f17',
#  'f18',
#  'f19',
#  'f20',
#  'f21',
#  'f22',
#  'f23',
#  'f24',
#  'f25',
#  'f26',
#  'f27',
#  'f28',
#  'f29',
#  'f30',
#  'f31',
#  'f32',
#  'f33',
#  'f34',
#  'f35',
#  'f36',
#  'f37',
#  'f38',
#  'f39',
#  'f40',
#  'f41',
#  'f42',
#  'f43',
#  'f44',
#  'f45',
#  'f46',
#  'f47',
#  'f48',
#  'f49',
#  'f50',
#  'f51',
#  'f52',
#  'f53',
#  'f54',
#  'f55',
#  'f56',
#  'f57',
#  'f58',
#  'f59',
#  'f60',
#  'f61',
#  'f62',
#  'f63',
#  'f64',
#  'f65',
#  'f66',
#  'f67',
#  'f68',
#  'f69',
#  'f70',
#  'f71',
#  'f72',
#  'f73',
#  'f74',
#  'f75',
#  'f76',
#  'f77',
#  'f78',
#  'f79',
#  'f80',
#  'f81',
#  'f82',
#  'f83',
#  'f84',
#  'f85',
#  'f86',
#  'f87',
#  'f88',
#  'f89',
#  'f90',
#  'f91',
#  'f92',
#  'f93',
#  'f94',
#  'f95',
#  'f96',
#  'f97',
#  'f98',
#  'f99',
#  'f100',
# ...

# %%
xtrain = df_train[features_list]
xtest = test[features_list]
mode = xtrain.mode().iloc[0]
xtrain =xtrain.fillna(mode)
xtest = xtest.fillna(mode)

# %%
xtrain['kfold'] = -1 #adding a column kfold with -1 values in it
kf = model_selection.KFold(n_splits =10, shuffle=True, random_state=0)
for fold, (train_idx, valid_idx) in enumerate(kf.split(X=xtrain)):
    xtrain.loc[valid_idx, 'kfold'] = fold
xtrain.head()
# Out:
#          f1        f2         f3        f4       f5        f6       f7  \
# id
# 0   0.10859  0.004314    -37.566  0.017364  0.28915 -10.25100   135.12
# 1   0.10090  0.299610  11822.000  0.276500  0.45970  -0.83733  1721.90
# 2   0.17803 -0.006980    907.270  0.272140  0.45948   0.17327  2298.00
# 3   0.15236  0.007259    780.100  0.025179  0.51947   7.49140   112.51
# 4   0.11623  0.502900   -109.150  0.297910  0.34490  -0.40932  2538.90
#
#           f8            f9        f10  ...    f111     f112      f113  \
# id                                     ...
# 0   168900.0  3.992400e+14     86.489  ...  1.7482  1.90960  -7.11570
# 1   119810.0  3.874100e+15   9953.600  ...  4.1684  0.34808   4.14200
# 2   360650.0  1.224500e+13  15827.000  ...  1.2042  0.26290   8.13120
# 3   259490.0  7.781400e+13    -36.837  ...  2.0694  0.79631 -16.33600
# 4    65332.0  1.907200e+15    144.120  ...  1.5298  1.14640  -0.43124
#
# ...

# %%
xtrain.to_csv('train_10folds.csv', index=False)
